# %% [markdown]
# <a href="https://colab.research.google.com/github/emilyswitzer/celeb-heights/blob/main/FinalCelebsHeight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import TensorFlow and other libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## Download and explore the dataset

# %%
# !unzip "/content/train.zip" -d "/"

# %%
# !unzip "/content/205.zip" -d "/content/205"

# %%
import pathlib
import glob
import cv2
#data_dir = "train/"
data_dir = "/content/205"
data_dir = pathlib.Path(data_dir)

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3153

# %%
person = list(data_dir.glob('191/*'))
PIL.Image.open(str(person[10]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=509x512 at 0x7F2A8C6D5E10>

# %% [markdown]
# # Load data using a Keras utility

# %% [markdown]
# ## Create a dataset

# %%
from keras.callbacks import ModelCheckpoint

# %%
batch_size = 8
#img_height = 256
#img_width = 211

img_height = 512
img_width = 509

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.3,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  #color_mode="grayscale",
  batch_size=batch_size)
# Out:
# Found 3153 files belonging to 67 classes.
# Using 2208 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.3,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
 # color_mode="grayscale",
  batch_size=batch_size)
# Out:
# Found 3153 files belonging to 67 classes.
# Using 945 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['106', '109', '111', '114', '116', '119', '121', '125', '127', '129', '130', '132', '139', '146', '147', '148', '149', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '177', '178', '179', '180', '181', '182', '183', '184', '185', '188', '190', '191', '192', '193', '194', '200', '201', '202', '203', '204', '205', '206', '207', '208', '209', '210']

# %% [markdown]
# ## Visualize the data

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (8, 512, 509, 3)
# (8,)

# %% [markdown]
# ## Standardize the data

# %% [markdown]
# The RGB channel values are in the `[0, 255]` range. To keep input values small  standardize values to be in the `[0, 1]` range.

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %% [markdown]
# # Create the model

# %% [markdown]
# ## Overfitting

# %% [markdown]
# ## Data augmentation

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %% [markdown]
# #Create the model with Overfitting Solutions

# %%
num_classes = len(class_names)


model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.3),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
 
  
])

# %%
num_classes = len(class_names)


model = Sequential([
  #data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(32, 3,padding='same', activation='relu'),
  layers.Conv2D(32, 3,padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3,padding='same', activation='relu'),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3,padding='same', activation='relu'),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(num_classes),
])

# %%
checkpoint = ModelCheckpoint('model.h5',  # model filename
                             monitor='val_loss', # quantity to monitor
                             verbose=0, # verbosity - 0 or 1
                             save_best_only= True, # The latest best model will not be overwritten
                             mode='auto') # The decision to overwrite model is made 
                                          # automatically depending on the quantity to monitor

# %% [markdown]
# x = list/ array of images
# y - list/array of number (height)

# %% [markdown]
# ## Compile and train the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 512, 509, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 512, 509, 3)       0
#
#  conv2d (Conv2D)             (None, 512, 509, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 256, 254, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 256, 254, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 128, 127, 32)     0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 128, 127, 64)      18496
#
#  max_pooling2d_2 (MaxPooling  (None, 64, 63, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 64, 63, 64)        0
#
#  flatten (Flatten)           (None, 258048)            0
#
#  dense (Dense)               (None, 128)               33030272
#
#  dense_1 (Dense)             (None, 68)                8772
#
# =================================================================
# Total params: 33,062,628
# Trainable params: 33,062,628
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs =
#   inflating: /content/unseen/content/unseen2/194.jpg
#   inflating: /content/unseen/content/unseen2/179.jpg
#   inflating: /content/unseen/content/unseen2/155.jpg
#   inflating: /content/unseen/content/unseen2/206.jpg
#   inflating: /content/unseen/content/unseen2/153.jpg
#   inflating: /content/unseen/content/unseen2/148.jpg
#   inflating: /content/unseen/content/unseen2/166.jpg
#   inflating: /content/unseen/content/unseen2/106.jpg
#   inflating: /content/unseen/content/unseen2/201.jpg
#   inflating: /content/unseen/content/unseen2/189.jpg
#   inflating: /content/unseen/content/unseen2/109.jpg
#   inflating: /content/unseen/content/unseen2/161.jpg
#   inflating: /content/unseen/content/unseen2/174.jpg
#   inflating: /content/unseen/content/unseen2/181.jpg
#   inflating: /content/unseen/content/unseen2/152.jpg
#   inflating: /content/unseen/content/unseen2/209.jpg
#   inflating: /content/unseen/content/unseen2/200.jpg
#   inflating: /content/unseen/content/unseen2/195.jpg
#   inflating: /content/unseen/content/unseen2/196.jpg
#   inflating: /content/unseen/content/unseen2/208.jpg
#   inflating: /content/unseen/content/unseen2/169.jpg
#   inflating: /content/unseen/content/unseen2/164.jpg
#   inflating: /content/unseen/content/unseen2/130.jpg
#   inflating: /content/unseen/content/unseen2/210.jpg
#   inflating: /content/unseen/content/unseen2/185.jpg
#   inflating: /content/unseen/content/unseen2/173.jpg
#   inflating: /content/unseen/content/unseen2/147.jpg
#   inflating: /content/unseen/content/unseen2/187.jpg
#   inflating: /content/unseen/content/unseen2/162.jpg
#   inflating: /content/unseen/content/unseen2/188.jpg
#   inflating: /content/unseen/content/unseen2/203.jpg
#   inflating: /content/unseen/content/unseen2/199.jpg
#   inflating: /content/unseen/content/unseen2/197.jpg
#   inflating: /content/unseen/content/unseen2/172.jpg
#   inflating: /content/unseen/content/unseen2/184.jpg
#   inflating: /content/unseen/content/unseen2/156.jpg
#   inflating: /content/unseen/content/unseen2/202.jpg
#   inflating: /content/unseen/content/unseen2/163.jpg
#   inflating: /content/unseen/content/unseen2/171.jpg
#   inflating: /content/unseen/content/unseen2/151.jpg
#   inflating: /content/unseen/content/unseen2/132.jpg
#   inflating: /content/unseen/content/unseen2/205.jpg
#   inflating: /content/unseen/content/unseen2/193.jpg
#   inflating: /content/unseen/content/unseen2/158.jpg
#   inflating: /content/unseen/content/unseen2/204.jpg
#   inflating: /content/unseen/content/unseen2/167.jpg
#   inflating: /content/unseen/content/unseen2/207.jpg

# %%
import matplotlib.image as mpimg
img = mpimg.imread('/content/167.jpg')
imgplot = plt.imshow(img)
plt.show()
sunflower_path = '/content/167.jpg'

img = tf.keras.utils.load_img(
    sunflower_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])




print(
    "The person is {:.2f} percent {} cm "
    .format(100 * np.max(score),class_names[np.argmax(score)])
)
# Out:
# The person is 2.30 percent 173 cm

# %%
import matplotlib.image as mpimg
img = mpimg.imread('/content/207.jpg')
imgplot = plt.imshow(img)
plt.show()
sunflower_path = '/content/207.jpg'

img = tf.keras.utils.load_img(
    sunflower_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])




print(
    "The person is {:.2f} percent {} cm "
    .format(100 * np.max(score),class_names[np.argmax(score)])
)
# Out:
# The person is 2.14 percent 165 cm
